# %%
import tensorflow as tf
from tensorflow.keras import Sequential,Model,Input
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, MaxPool2D, Conv2DTranspose, Cropping2D
from tensorflow.keras.layers import Add, Dropout, Permute, add
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers, backend #Adam
import matplotlib.pyplot as plt
# %load_ext tensorboard
from tensorboard import notebook
import datetime,os
import numpy as np

from data_processing import prepare_data
from metrics.intersection_over_union import iou

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ![Fast-SCNN Architecture](https://github.com/DeepVoltaire/Fast-SCNN/raw/master/figures/fast-scnn.png)

# %%
#for this file, I modified the structure of the original one. 
#I removed the first two DSConv blocks, I changed the second upsample from (8,8) to (2,2)

# %% [markdown]
# #### Custom function for conv2d: conv_block

# %%
def conv_block(inputs, conv_type, kernel, kernel_size, strides, padding='same', relu=True):
    if(conv_type == 'ds'):
        x = tf.keras.layers.SeparableConv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)
    else:
        x = tf.keras.layers.Conv2D(kernel, kernel_size, padding=padding, strides = strides)(inputs)  

    x = tf.keras.layers.BatchNormalization()(x)

    if (relu):
        x = tf.keras.activations.relu(x)

    return x

# %% [markdown]
# ## Step 1: Learning to DownSample

# %%
# Input Layer
input_layer = tf.keras.layers.Input(shape=(256, 256, 3), name = 'input_layer', batch_size=16)

# %%
lds_layer = conv_block(input_layer, 'conv', 32, (3, 3), strides = (2, 2))
# lds_layer = conv_block(lds_layer, 'ds', 48, (3, 3), strides = (2, 2))
# lds_layer = conv_block(lds_layer, 'ds', 64, (3, 3), strides = (2, 2))

# %% [markdown]
# ## Step 2: Global Feature Extractor

# %% [markdown]
# #### residual custom method

# %%
def _res_bottleneck(inputs, filters, kernel, t, s, r=False):
    tchannel = tf.keras.backend.int_shape(inputs)[-1] * t

    x = conv_block(inputs, 'conv', tchannel, (1, 1), strides=(1, 1))

    x = tf.keras.layers.DepthwiseConv2D(kernel, strides=(s, s), depth_multiplier=1, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)

    x = conv_block(x, 'conv', filters, (1, 1), strides=(1, 1), padding='same', relu=False)

    if r:
        x = tf.keras.layers.add([x, inputs])
    return x

# %% [markdown]
# #### Bottleneck custom method

# %%
def bottleneck_block(inputs, filters, kernel, t, strides, n):
    x = _res_bottleneck(inputs, filters, kernel, t, strides)

    for i in range(1, n):
        x = _res_bottleneck(x, filters, kernel, t, 1, True)

    return x

# %% [markdown]
# #### PPM Method

# %%
def pyramid_pooling_block(input_tensor, bin_sizes):
    concat_list = [input_tensor]
    #   w = 64
    #   h = 32
    w = 32
    h = 32

    for bin_size in bin_sizes:
        x = tf.keras.layers.AveragePooling2D(pool_size=(w//bin_size, h//bin_size), strides=(w//bin_size, h//bin_size))(input_tensor)
        x = tf.keras.layers.Conv2D(128, 3, 2, padding='same')(x)
        x = tf.keras.layers.Lambda(lambda x: tf.image.resize(x, (w,h)))(x)
        concat_list.append(x)

    return tf.keras.layers.concatenate(concat_list)

# %% [markdown]
# #### Assembling all the methods

# %%
gfe_layer = bottleneck_block(lds_layer, 64, (3, 3), t=6, strides=2, n=3)
gfe_layer = bottleneck_block(gfe_layer, 96, (3, 3), t=6, strides=2, n=3)
gfe_layer = bottleneck_block(gfe_layer, 128, (3, 3), t=6, strides=1, n=3)
gfe_layer = pyramid_pooling_block(gfe_layer, [2,4,6,8])

# %% [markdown]
# ## Step 3: Feature Fusion

# %%
ff_layer1 = conv_block(lds_layer, 'conv', 128, (1,1), padding='same', strides= (1,1), relu=False)

# %%
ff_layer2 = tf.keras.layers.UpSampling2D((4, 4))(gfe_layer)
ff_layer2 = tf.keras.layers.DepthwiseConv2D((3,3), strides=(1, 1), depth_multiplier=1, padding='same')(ff_layer2)
ff_layer2 = tf.keras.layers.BatchNormalization()(ff_layer2)
ff_layer2 = tf.keras.activations.relu(ff_layer2)
ff_layer2 = tf.keras.layers.Conv2D(128, 1, 1, padding='same', activation=None)(ff_layer2)

# %%
ff_final = tf.keras.layers.add([ff_layer1, ff_layer2])
ff_final = tf.keras.layers.BatchNormalization()(ff_final)
ff_final = tf.keras.activations.relu(ff_final)

# %% [markdown]
# ## Step 4: Classifier

# %%
classifier = tf.keras.layers.SeparableConv2D(128, (3, 3), padding='same', strides = (1, 1), name = 'DSConv1_classifier')(ff_final)
classifier = tf.keras.layers.BatchNormalization()(classifier)
classifier = tf.keras.activations.relu(classifier)

classifier = tf.keras.layers.SeparableConv2D(128, (3, 3), padding='same', strides = (1, 1), name = 'DSConv2_classifier')(classifier)
classifier = tf.keras.layers.BatchNormalization()(classifier)
classifier = tf.keras.activations.relu(classifier)

num_of_classes=2
classifier = conv_block(classifier, 'conv', num_of_classes, (1, 1), strides=(1, 1), padding='same', relu=False)

classifier = tf.keras.layers.Dropout(0.3)(classifier)

classifier = tf.keras.layers.UpSampling2D((2, 2))(classifier)
classifier = tf.keras.activations.softmax(classifier)

# %% [markdown]
# ## Model Compilation

# %%
fast_scnn = tf.keras.Model(inputs = input_layer , outputs = classifier, name = 'Fast_SCNN')
fast_scnn.compile(optimizer = optimizers.Adam(lr = 0.045), loss="categorical_crossentropy", metrics=[iou, 'accuracy'])

# %%
fast_scnn.summary()
# Out:
# Model: "Fast_SCNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(16, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (16, 128, 128, 32)   896         input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (16, 128, 128, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu (TensorFlowOpL [(16, 128, 128, 32)] 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (16, 128, 128, 192)  6336        tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (16, 128, 128, 192)  768         conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_1 (TensorFlowO [(16, 128, 128, 192) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (16, 64, 64, 192)    1920        tf_op_layer_Relu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (16, 64, 64, 192)    768         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_2 (TensorFlowO [(16, 64, 64, 192)]  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (16, 64, 64, 64)     12352       tf_op_layer_Relu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (16, 64, 64, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (16, 64, 64, 384)    24960       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (16, 64, 64, 384)    1536        conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_3 (TensorFlowO [(16, 64, 64, 384)]  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (16, 64, 64, 384)    3840        tf_op_layer_Relu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (16, 64, 64, 384)    1536        depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_4 (TensorFlowO [(16, 64, 64, 384)]  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (16, 64, 64, 64)     24640       tf_op_layer_Relu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (16, 64, 64, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (16, 64, 64, 64)     0           batch_normalization_6[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (16, 64, 64, 384)    24960       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (16, 64, 64, 384)    1536        conv2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_5 (TensorFlowO [(16, 64, 64, 384)]  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (16, 64, 64, 384)    3840        tf_op_layer_Relu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (16, 64, 64, 384)    1536        depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_6 (TensorFlowO [(16, 64, 64, 384)]  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (16, 64, 64, 64)     24640       tf_op_layer_Relu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (16, 64, 64, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (16, 64, 64, 64)     0           batch_normalization_9[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (16, 64, 64, 384)    24960       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (16, 64, 64, 384)    1536        conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_7 (TensorFlowO [(16, 64, 64, 384)]  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (16, 32, 32, 384)    3840        tf_op_layer_Relu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (16, 32, 32, 384)    1536        depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_8 (TensorFlowO [(16, 32, 32, 384)]  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (16, 32, 32, 96)     36960       tf_op_layer_Relu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (16, 32, 32, 96)     384         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (16, 32, 32, 576)    55872       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (16, 32, 32, 576)    2304        conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_9 (TensorFlowO [(16, 32, 32, 576)]  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (16, 32, 32, 576)    5760        tf_op_layer_Relu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (16, 32, 32, 576)    2304        depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_10 (TensorFlow [(16, 32, 32, 576)]  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (16, 32, 32, 96)     55392       tf_op_layer_Relu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (16, 32, 32, 96)     384         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (16, 32, 32, 96)     0           batch_normalization_15[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (16, 32, 32, 576)    55872       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (16, 32, 32, 576)    2304        conv2d_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_11 (TensorFlow [(16, 32, 32, 576)]  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (16, 32, 32, 576)    5760        tf_op_layer_Relu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (16, 32, 32, 576)    2304        depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_12 (TensorFlow [(16, 32, 32, 576)]  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (16, 32, 32, 96)     55392       tf_op_layer_Relu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (16, 32, 32, 96)     384         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (16, 32, 32, 96)     0           batch_normalization_18[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (16, 32, 32, 576)    55872       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (16, 32, 32, 576)    2304        conv2d_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_13 (TensorFlow [(16, 32, 32, 576)]  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (16, 32, 32, 576)    5760        tf_op_layer_Relu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (16, 32, 32, 576)    2304        depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_14 (TensorFlow [(16, 32, 32, 576)]  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (16, 32, 32, 128)    73856       tf_op_layer_Relu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (16, 32, 32, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (16, 32, 32, 768)    99072       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (16, 32, 32, 768)    3072        conv2d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_15 (TensorFlow [(16, 32, 32, 768)]  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (16, 32, 32, 768)    7680        tf_op_layer_Relu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (16, 32, 32, 768)    3072        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_16 (TensorFlow [(16, 32, 32, 768)]  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (16, 32, 32, 128)    98432       tf_op_layer_Relu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (16, 32, 32, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (16, 32, 32, 128)    0           batch_normalization_24[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (16, 32, 32, 768)    99072       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (16, 32, 32, 768)    3072        conv2d_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_17 (TensorFlow [(16, 32, 32, 768)]  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (16, 32, 32, 768)    7680        tf_op_layer_Relu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (16, 32, 32, 768)    3072        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_18 (TensorFlow [(16, 32, 32, 768)]  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (16, 32, 32, 128)    98432       tf_op_layer_Relu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (16, 32, 32, 128)    512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (16, 32, 32, 128)    0           batch_normalization_27[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (16, 2, 2, 128)      0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (16, 4, 4, 128)      0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (16, 6, 6, 128)      0           add_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (16, 8, 8, 128)      0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (16, 1, 1, 128)      147584      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (16, 2, 2, 128)      147584      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (16, 3, 3, 128)      147584      average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (16, 4, 4, 128)      147584      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (16, 32, 32, 128)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (16, 32, 32, 128)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (16, 32, 32, 128)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (16, 32, 32, 128)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (16, 32, 32, 640)    0           add_5[0][0]
#                                                                  lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (16, 128, 128, 640)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (16, 128, 128, 640)  6400        up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (16, 128, 128, 640)  2560        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (16, 128, 128, 128)  4224        tf_op_layer_Relu[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_19 (TensorFlow [(16, 128, 128, 640) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (16, 128, 128, 128)  512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (16, 128, 128, 128)  82048       tf_op_layer_Relu_19[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (16, 128, 128, 128)  0           batch_normalization_28[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (16, 128, 128, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_20 (TensorFlow [(16, 128, 128, 128) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# DSConv1_classifier (SeparableCo (16, 128, 128, 128)  17664       tf_op_layer_Relu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (16, 128, 128, 128)  512         DSConv1_classifier[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_21 (TensorFlow [(16, 128, 128, 128) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# DSConv2_classifier (SeparableCo (16, 128, 128, 128)  17664       tf_op_layer_Relu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (16, 128, 128, 128)  512         DSConv2_classifier[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_22 (TensorFlow [(16, 128, 128, 128) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (16, 128, 128, 2)    258         tf_op_layer_Relu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (16, 128, 128, 2)    8           conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (16, 128, 128, 2)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (16, 256, 256, 2)    0           dropout[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Max (TensorFlowOpLa [(16, 256, 256, 1)]  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub (TensorFlowOpLa [(16, 256, 256, 2)]  0           up_sampling2d_1[0][0]
#                                                                  tf_op_layer_Max[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(16, 256, 256, 2)]  0           tf_op_layer_sub[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(16, 256, 256, 1)]  0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv (TensorFlow [(16, 256, 256, 2)]  0           tf_op_layer_Exp[0][0]
#                                                                  tf_op_layer_Sum[0][0]
# ==================================================================================================
# Total params: 1,737,706
# Trainable params: 1,715,174
# Non-trainable params: 22,532
# __________________________________________________________________________________________________

# %%
# tf.keras.utils.plot_model(fast_scnn, show_layer_names=True, show_shapes=True)
tb = TensorBoard(log_dir='training_logs/test_log1', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='trained_models/test1.h5', monitor='iou', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='min', monitor='val_loss', patience=50, verbose=1)
callbacks = [tb, mc, es]
num_epochs=20
fast_scnn.load_weights('trained_models/fast_scnn_1.h5')
fast_scnn.fit(prepare_data.train_data_generator(batch_size=16), steps_per_epoch=246 ,
                validation_data = prepare_data.validation_data_generator(batch_size=16), 
                validation_steps = 84, epochs=num_epochs, callbacks=callbacks, verbose=1)

# %%
fast_scnn.load_weights('trained_models/fast_scnn_1.h5')
result=fast_scnn.evaluate(prepare_data.test_data_generator(batch_size=16),steps=85)
print(result)

# %%
fast_scnn.load_weights('trained_models/fast_scnn_1.h5')
testing_gen = prepare_data.test_data_generator(batch_size=16)
#testing_gen=PrepareData.images_without_label_data_generator(batch_size=16)
flag=1
while(flag>0):
    flag=flag-1
    batch_img, batch_mask= next(testing_gen)
    #batch_img = next(testing_gen)
    pred_all = fast_scnn.predict(batch_img)
    np.shape(pred_all)
    for i in range(0, np.shape(pred_all)[0]):
        fig = plt.figure(figsize=(20, 8))

        ax1 = fig.add_subplot(1, 3, 1)
        ax1.imshow(batch_img[i])
        ax1.title.set_text('Original Image')
        ax1.grid(b=None)

        ax2 = fig.add_subplot(1, 3, 2)
        ax2.set_title('Ground truth labels')
        ax2.imshow(prepare_data.onehot_to_rgb(batch_mask[i], prepare_data.id2code))
        ax2.grid(b=None)

        ax3 = fig.add_subplot(1, 3, 3)
        ax3.set_title('Predicted labels')
        new_color_code={0: (0, 0, 0), 1: (135,206,235)}
        ax3.imshow(prepare_data.onehot_to_rgb(pred_all[i], new_color_code))
        ax3.grid(b=None)
        plt.show()
# Out:
# Found 1360 images belonging to 2 classes.
# Found 1360 images belonging to 2 classes.

# %%
# %tensorboard --logdir fast_scnn_logs2
