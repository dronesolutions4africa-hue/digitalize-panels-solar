# %%
import tensorflow as tf
from tensorflow.keras import Model, Input, metrics
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import backend
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
# %load_ext tensorboard
from tensorboard import notebook
import datetime,os
import numpy as np

from metrics.intersection_over_union import iou
from pooling_layers.max_pooling import MaxPoolingWithArgmax2D
from pooling_layers.max_unpooling import MaxUnpooling2D
from data_processing import prepare_data

# %%
def conv_block_3(input_tensor, kernel_size, filters, stage, block):
    """Conv block.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of
            middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    """
    filters1, filters2, filters3 = filters
    if backend.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    if input_tensor.shape[3] ==filters3:
        shortcut = input_tensor
    else:
        shortcut = layers.Conv2D(filters3, (1, 1))(input_tensor)
        
    x = layers.Conv2D(filters1, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size,
                      padding='same',
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2b')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# %%
def identity_block_3(input_tensor, kernel_size, filters, stage, block, next_layer_filter):
    """Identity block
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
        next_layer_filter: in segnet previous mask will be added to unpool, 
        need to make sure they have same number of filters
    # Returns
        Output tensor for the block.
    """
    filters1, filters2, filters3 = filters
    if backend.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    if input_tensor.shape[3] ==filters3:
        shortcut = input_tensor
    else:
        shortcut = layers.Conv2D(filters3, (1, 1))(input_tensor)
        
    x = layers.Conv2D(filters1, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size,
                      padding='same',
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2b')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    if x.shape[3]!=next_layer_filter:
        x=layers.Conv2D(next_layer_filter, (1, 1))(x)
    return x

# %%
def SegNet(input_shape, batch_size, n_labels=2, kernel=3, pool_size=(2, 2), output_mode="softmax", model_summary=None):
    # encoder
    inputs = Input(shape=input_shape, batch_size=batch_size)
    conv_1=conv_block_3(input_tensor=inputs, kernel_size=(kernel,kernel), filters=[64,64,64],stage=1, block='a')
    pool_1, mask_1 = MaxPoolingWithArgmax2D(pool_size)(conv_1)
    conv_2=conv_block_3(input_tensor=pool_1, kernel_size=(kernel,kernel), filters=[128,128,128], stage=2, block='a')
    pool_2, mask_2 = MaxPoolingWithArgmax2D(pool_size)(conv_2)
    conv_3=conv_block_3(input_tensor=pool_2, kernel_size=(kernel,kernel), filters=[128,128,128], stage=3, block='a')
    pool_3, mask_3 = MaxPoolingWithArgmax2D(pool_size)(conv_3)
    conv_4=conv_block_3(input_tensor=pool_3, kernel_size=(kernel,kernel), filters=[256,256,256], stage=4, block='a')
    pool_4, mask_4 = MaxPoolingWithArgmax2D(pool_size)(conv_4)
    conv_5=conv_block_3(input_tensor=pool_4, kernel_size=(kernel,kernel), filters=[256,256,256], stage=5, block='a')
    pool_5, mask_5 = MaxPoolingWithArgmax2D(pool_size)(conv_5)
    print("Build enceder done..")
    

    # decoder
    unpool_1 = MaxUnpooling2D(pool_size)([pool_5, mask_5])
    conv_6=identity_block_3(input_tensor=unpool_1, kernel_size=(kernel,kernel), filters=[256,256,256], stage=6, block='a', next_layer_filter=256)
    unpool_2 = MaxUnpooling2D(pool_size)([conv_6, mask_4])
    conv_7=identity_block_3(input_tensor=unpool_2, kernel_size=(kernel,kernel), filters=[256,256,256], stage=7, block='a', next_layer_filter=128)
    unpool_3 = MaxUnpooling2D(pool_size)([conv_7, mask_3])
    conv_8=identity_block_3(input_tensor=unpool_3, kernel_size=(kernel,kernel), filters=[128,128,128], stage=8, block='a', next_layer_filter=128)
    unpool_4 = MaxUnpooling2D(pool_size)([conv_8, mask_2])
    conv_9=identity_block_3(input_tensor=unpool_4, kernel_size=(kernel,kernel), filters=[128,128,128], stage=9, block='a', next_layer_filter=64)
    unpool_5 = MaxUnpooling2D(pool_size)([conv_9, mask_1])
    conv_10=identity_block_3(input_tensor=unpool_5, kernel_size=(kernel,kernel), filters=[64,64,64], stage=10, block='a', next_layer_filter=64)

    out=layers.Conv2D(n_labels,1, activation = output_mode)(conv_10)
    print("Build decoder done..")

    model = Model(inputs=inputs, outputs=out, name="SegNet")
    model.compile(optimizer = optimizers.Adam(lr = 1e-3), loss = 'categorical_crossentropy',metrics=[iou,'accuracy'])

    if model_summary is True:
        model.summary()

    return model

# %%
tb = TensorBoard(log_dir='training_logs/test_log1', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='trained_models/test1.h5', monitor='iou', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='min', monitor='val_loss', patience=50, verbose=1)
callbacks = [tb, mc, es]
batch_size = 16
model=SegNet(input_shape=(256, 256, 3), batch_size=batch_size, n_labels=2, model_summary=True)
num_epochs = 25
model.fit(prepare_data.train_data_generator(batch_size=16),
                    validation_data=prepare_data.validation_data_generator(batch_size=16),epochs=num_epochs, 
                    verbose=1,steps_per_epoch=246, validation_steps=84,callbacks=callbacks)

# %%
model=SegNet(input_shape=(256, 256, 3),batch_size=16, n_labels=2, model_summary=True)
model.load_weights('trained_models/seg_resnet_1.h5')
result=model.evaluate(prepare_data.test_data_generator(batch_size=16),steps=85)
print(result)

# %%
model=SegNet(input_shape=(256, 256, 3), batch_size=16, n_labels=2, model_summary=True)
model.load_weights('trained_models/seg_resnet_1.h5')
flag=1
testing_gen = prepare_data.test_data_generator(batch_size=16, seed=20)
#testing_gen=PrepareData.images_without_label_data_generator(batch_size=16)
while(flag>0):
    flag=flag-1
    batch_img, batch_mask= next(testing_gen)
    #batch_img = next(testing_gen)
    pred_all = model.predict(batch_img)
    np.shape(pred_all)

    for i in range(0, np.shape(pred_all)[0]):
        fig = plt.figure(figsize=(20, 8))

        ax1 = fig.add_subplot(1, 3, 1)
        ax1.imshow(batch_img[i])
        ax1.title.set_text('Original Image')
        ax1.grid(b=None)

        ax2 = fig.add_subplot(1, 3, 2)
        ax2.set_title('Ground truth labels')
        ax2.imshow(prepare_data.onehot_to_rgb(batch_mask[i], prepare_data.id2code))
        ax2.grid(b=None)

        ax3 = fig.add_subplot(1, 3, 3)
        ax3.set_title('Predicted labels')
        #Use a different color for prediction
        new_color_code={0: (0, 0, 0), 1: (135,206,235)}
        ax3.imshow(prepare_data.onehot_to_rgb(pred_all[i], new_color_code))
        ax3.grid(b=None)
        plt.show()
# Out:
# Build enceder done..
# Build decoder done..
# Model: "SegNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(16, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# res1a_branch2a (Conv2D)         (16, 256, 256, 64)   256         input_2[0][0]
# __________________________________________________________________________________________________
# bn1a_branch2a (BatchNormalizati (16, 256, 256, 64)   256         res1a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (16, 256, 256, 64)   0           bn1a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1a_branch2b (Conv2D)         (16, 256, 256, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# bn1a_branch2b (BatchNormalizati (16, 256, 256, 64)   256         res1a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (16, 256, 256, 64)   0           bn1a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1a_branch2c (Conv2D)         (16, 256, 256, 64)   4160        activation_31[0][0]
# __________________________________________________________________________________________________
# bn1a_branch2c (BatchNormalizati (16, 256, 256, 64)   256         res1a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (16, 256, 256, 64)   256         input_2[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (16, 256, 256, 64)   0           bn1a_branch2c[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (16, 256, 256, 64)   0           add_10[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_5 (Ma [(16, 128, 128, 64), 0           activation_32[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (16, 128, 128, 128)  8320        max_pooling_with_argmax2d_5[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (16, 128, 128, 128)  512         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (16, 128, 128, 128)  0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (16, 128, 128, 128)  147584      activation_33[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (16, 128, 128, 128)  512         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (16, 128, 128, 128)  0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (16, 128, 128, 128)  16512       activation_34[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (16, 128, 128, 128)  512         res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (16, 128, 128, 128)  8320        max_pooling_with_argmax2d_5[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (16, 128, 128, 128)  0           bn2a_branch2c[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (16, 128, 128, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_6 (Ma [(16, 64, 64, 128),  0           activation_35[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (16, 64, 64, 128)    16512       max_pooling_with_argmax2d_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (16, 64, 64, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (16, 64, 64, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (16, 64, 64, 128)    147584      activation_36[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (16, 64, 64, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (16, 64, 64, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (16, 64, 64, 128)    16512       activation_37[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (16, 64, 64, 128)    512         res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (16, 64, 64, 128)    0           bn3a_branch2c[0][0]
#                                                                  max_pooling_with_argmax2d_6[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (16, 64, 64, 128)    0           add_12[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_7 (Ma [(16, 32, 32, 128),  0           activation_38[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (16, 32, 32, 256)    33024       max_pooling_with_argmax2d_7[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (16, 32, 32, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (16, 32, 32, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (16, 32, 32, 256)    590080      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (16, 32, 32, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (16, 32, 32, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (16, 32, 32, 256)    65792       activation_40[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (16, 32, 32, 256)    1024        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (16, 32, 32, 256)    33024       max_pooling_with_argmax2d_7[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (16, 32, 32, 256)    0           bn4a_branch2c[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (16, 32, 32, 256)    0           add_13[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_8 (Ma [(16, 16, 16, 256),  0           activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (16, 16, 16, 256)    65792       max_pooling_with_argmax2d_8[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (16, 16, 16, 256)    1024        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (16, 16, 16, 256)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (16, 16, 16, 256)    590080      activation_42[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (16, 16, 16, 256)    1024        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (16, 16, 16, 256)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (16, 16, 16, 256)    65792       activation_43[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (16, 16, 16, 256)    1024        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (16, 16, 16, 256)    0           bn5a_branch2c[0][0]
#                                                                  max_pooling_with_argmax2d_8[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (16, 16, 16, 256)    0           add_14[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_9 (Ma [(16, 8, 8, 256), (1 0           activation_44[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_5 (MaxUnpooling (16, 16, 16, 256)    0           max_pooling_with_argmax2d_9[0][0]
#                                                                  max_pooling_with_argmax2d_9[0][1]
# __________________________________________________________________________________________________
# res6a_branch2a (Conv2D)         (16, 16, 16, 256)    65792       max_unpooling2d_5[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2a (BatchNormalizati (16, 16, 16, 256)    1024        res6a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (16, 16, 16, 256)    0           bn6a_branch2a[0][0]
# __________________________________________________________________________________________________
# res6a_branch2b (Conv2D)         (16, 16, 16, 256)    590080      activation_45[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2b (BatchNormalizati (16, 16, 16, 256)    1024        res6a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (16, 16, 16, 256)    0           bn6a_branch2b[0][0]
# __________________________________________________________________________________________________
# res6a_branch2c (Conv2D)         (16, 16, 16, 256)    65792       activation_46[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2c (BatchNormalizati (16, 16, 16, 256)    1024        res6a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (16, 16, 16, 256)    0           bn6a_branch2c[0][0]
#                                                                  max_unpooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (16, 16, 16, 256)    0           add_15[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_6 (MaxUnpooling (16, 32, 32, 256)    0           activation_47[0][0]
#                                                                  max_pooling_with_argmax2d_8[0][1]
# __________________________________________________________________________________________________
# res7a_branch2a (Conv2D)         (16, 32, 32, 256)    65792       max_unpooling2d_6[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2a (BatchNormalizati (16, 32, 32, 256)    1024        res7a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (16, 32, 32, 256)    0           bn7a_branch2a[0][0]
# __________________________________________________________________________________________________
# res7a_branch2b (Conv2D)         (16, 32, 32, 256)    590080      activation_48[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2b (BatchNormalizati (16, 32, 32, 256)    1024        res7a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (16, 32, 32, 256)    0           bn7a_branch2b[0][0]
# __________________________________________________________________________________________________
# res7a_branch2c (Conv2D)         (16, 32, 32, 256)    65792       activation_49[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2c (BatchNormalizati (16, 32, 32, 256)    1024        res7a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (16, 32, 32, 256)    0           bn7a_branch2c[0][0]
#                                                                  max_unpooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (16, 32, 32, 256)    0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (16, 32, 32, 128)    32896       activation_50[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_7 (MaxUnpooling (16, 64, 64, 128)    0           conv2d_9[0][0]
#                                                                  max_pooling_with_argmax2d_7[0][1]
# __________________________________________________________________________________________________
# res8a_branch2a (Conv2D)         (16, 64, 64, 128)    16512       max_unpooling2d_7[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2a (BatchNormalizati (16, 64, 64, 128)    512         res8a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (16, 64, 64, 128)    0           bn8a_branch2a[0][0]
# __________________________________________________________________________________________________
# res8a_branch2b (Conv2D)         (16, 64, 64, 128)    147584      activation_51[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2b (BatchNormalizati (16, 64, 64, 128)    512         res8a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (16, 64, 64, 128)    0           bn8a_branch2b[0][0]
# __________________________________________________________________________________________________
# res8a_branch2c (Conv2D)         (16, 64, 64, 128)    16512       activation_52[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2c (BatchNormalizati (16, 64, 64, 128)    512         res8a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (16, 64, 64, 128)    0           bn8a_branch2c[0][0]
#                                                                  max_unpooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (16, 64, 64, 128)    0           add_17[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_8 (MaxUnpooling (16, 128, 128, 128)  0           activation_53[0][0]
#                                                                  max_pooling_with_argmax2d_6[0][1]
# __________________________________________________________________________________________________
# res9a_branch2a (Conv2D)         (16, 128, 128, 128)  16512       max_unpooling2d_8[0][0]
# __________________________________________________________________________________________________
# bn9a_branch2a (BatchNormalizati (16, 128, 128, 128)  512         res9a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (16, 128, 128, 128)  0           bn9a_branch2a[0][0]
# __________________________________________________________________________________________________
# res9a_branch2b (Conv2D)         (16, 128, 128, 128)  147584      activation_54[0][0]
# __________________________________________________________________________________________________
# bn9a_branch2b (BatchNormalizati (16, 128, 128, 128)  512         res9a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (16, 128, 128, 128)  0           bn9a_branch2b[0][0]
# __________________________________________________________________________________________________
# res9a_branch2c (Conv2D)         (16, 128, 128, 128)  16512       activation_55[0][0]
# __________________________________________________________________________________________________
# bn9a_branch2c (BatchNormalizati (16, 128, 128, 128)  512         res9a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (16, 128, 128, 128)  0           bn9a_branch2c[0][0]
#                                                                  max_unpooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (16, 128, 128, 128)  0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (16, 128, 128, 64)   8256        activation_56[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_9 (MaxUnpooling (16, 256, 256, 64)   0           conv2d_10[0][0]
#                                                                  max_pooling_with_argmax2d_5[0][1]
# __________________________________________________________________________________________________
# res10a_branch2a (Conv2D)        (16, 256, 256, 64)   4160        max_unpooling2d_9[0][0]
# __________________________________________________________________________________________________
# bn10a_branch2a (BatchNormalizat (16, 256, 256, 64)   256         res10a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (16, 256, 256, 64)   0           bn10a_branch2a[0][0]
# __________________________________________________________________________________________________
# res10a_branch2b (Conv2D)        (16, 256, 256, 64)   36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn10a_branch2b (BatchNormalizat (16, 256, 256, 64)   256         res10a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (16, 256, 256, 64)   0           bn10a_branch2b[0][0]
# __________________________________________________________________________________________________
# res10a_branch2c (Conv2D)        (16, 256, 256, 64)   4160        activation_58[0][0]
# __________________________________________________________________________________________________
# bn10a_branch2c (BatchNormalizat (16, 256, 256, 64)   256         res10a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (16, 256, 256, 64)   0           bn10a_branch2c[0][0]
#                                                                  max_unpooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (16, 256, 256, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (16, 256, 256, 2)    130         activation_59[0][0]
# ==================================================================================================
# Total params: 3,757,570
# Trainable params: 3,747,586
# Non-trainable params: 9,984
# __________________________________________________________________________________________________
# Found 1360 images belonging to 2 classes.
# Found 1360 images belonging to 2 classes.

# %%
# %tensorboard --logdir training_logs/logs14
#!tensorboard --logdir /tmp/whatever
