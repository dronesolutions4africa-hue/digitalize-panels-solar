# %%
import tensorflow as tf
from tensorflow.keras import Model, Input, metrics
from tensorflow.keras import layers 
from tensorflow.keras import optimizers
from tensorflow.keras import backend
from tensorflow.python.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
# %load_ext tensorboard
from tensorboard import notebook
import datetime,os
import numpy as np

from metrics.intersection_over_union import iou
from pooling_layers.max_pooling import MaxPoolingWithArgmax2D
from pooling_layers.max_unpooling import MaxUnpooling2D
from data_processing import prepare_data

# %%
def conv_block(input_tensor, kernel_size, filters, stage, block):
    """Conv block.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of
            middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
    # Returns
        Output tensor for the block.
    """
    if backend.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    #assume all the filters are the same value
    if input_tensor.shape[3] ==filters[0]:
        shortcut = input_tensor
    else:
        shortcut = layers.Conv2D(filters[0], (1, 1))(input_tensor)
        
    x = layers.Conv2D(filters[0], (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)
    for i in range(1,len(filters)-1):
        x = layers.Conv2D(filters[i], kernel_size,
                          padding='same',
                          kernel_initializer='he_normal',
                          name=conv_name_base + '2b'+str(i))(x)
        x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b'+str(i))(x)
        x = layers.Activation('relu')(x)

        
    x = layers.Conv2D(filters[len(filters)-1], (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# %%
def identity_block(input_tensor, kernel_size, filters, stage, block, next_layer_filter):
    """Identity block
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3
        filters: list of integers, the filters of 3 conv layer at main path
        stage: integer, current stage label, used for generating layer names
        block: 'a','b'..., current block label, used for generating layer names
        next_layer_filter: in segnet previous mask will be added to unpool, 
        need to make sure they have same number of filters
    # Returns
        Output tensor for the block.
    """
    if backend.image_data_format() == 'channels_last':
        bn_axis = 3
    else:
        bn_axis = 1
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    if input_tensor.shape[3] ==filters[0]:
        shortcut = input_tensor
    else:
        shortcut = layers.Conv2D(filters[0], (1, 1))(input_tensor)
        
    x = layers.Conv2D(filters[0], (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    for i in range(1,len(filters)-1):
        x = layers.Conv2D(filters[i], kernel_size,
                          padding='same',
                          kernel_initializer='he_normal',
                          name=conv_name_base + '2b'+str(i))(x)
        x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b'+str(i))(x)
        x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters[len(filters)-1], (1, 1),
                      kernel_initializer='he_normal',
                      name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    if x.shape[3]!=next_layer_filter:
        x=layers.Conv2D(next_layer_filter, (1, 1))(x)
    return x

# %%
def SegNet(input_shape, batch_size, n_labels=2, kernel=3, pool_size=(2, 2), output_mode="softmax", model_summary=None):
    # encoder
    inputs = Input(shape=input_shape, batch_size=batch_size)
    conv_1=conv_block(input_tensor=inputs, kernel_size=(kernel,kernel), filters=[64,64,64],stage=1, block='a')
    pool_1, mask_1 = MaxPoolingWithArgmax2D(pool_size)(conv_1)
    conv_2=conv_block(input_tensor=pool_1, kernel_size=(kernel,kernel), filters=[128,128,128], stage=2, block='a')
    pool_2, mask_2 = MaxPoolingWithArgmax2D(pool_size)(conv_2)
    conv_3=conv_block(input_tensor=pool_2, kernel_size=(kernel,kernel), filters=[128,128,128,128], stage=3, block='a')
    pool_3, mask_3 = MaxPoolingWithArgmax2D(pool_size)(conv_3)
    conv_4=conv_block(input_tensor=pool_3, kernel_size=(kernel,kernel), filters=[256,256,256,256,256], stage=4, block='a')
    pool_4, mask_4 = MaxPoolingWithArgmax2D(pool_size)(conv_4)
    conv_5=conv_block(input_tensor=pool_4, kernel_size=(kernel,kernel), filters=[256,256,256,256,256], stage=5, block='a')
    pool_5, mask_5 = MaxPoolingWithArgmax2D(pool_size)(conv_5)
    print("Build enceder done..")
    

    # decoder
    unpool_1 = MaxUnpooling2D(pool_size)([pool_5, mask_5])
    conv_6=identity_block(input_tensor=unpool_1, kernel_size=(kernel,kernel), filters=[256,256,256,256,256], stage=6, block='a', next_layer_filter=256)
    unpool_2 = MaxUnpooling2D(pool_size)([conv_6, mask_4])
    conv_7=identity_block(input_tensor=unpool_2, kernel_size=(kernel,kernel), filters=[256,256,256,256,256], stage=7, block='a', next_layer_filter=128)
    unpool_3 = MaxUnpooling2D(pool_size)([conv_7, mask_3])
    conv_8=identity_block(input_tensor=unpool_3, kernel_size=(kernel,kernel), filters=[128,128,128,128], stage=8, block='a', next_layer_filter=128)
    unpool_4 = MaxUnpooling2D(pool_size)([conv_8, mask_2])
    conv_9=identity_block(input_tensor=unpool_4, kernel_size=(kernel,kernel), filters=[128,128,128], stage=9, block='a', next_layer_filter=64)
    unpool_5 = MaxUnpooling2D(pool_size)([conv_9, mask_1])
    conv_10=identity_block(input_tensor=unpool_5, kernel_size=(kernel,kernel), filters=[64,64,64], stage=10, block='a', next_layer_filter=64)

    out=layers.Conv2D(n_labels,1, activation = output_mode)(conv_10)
    print("Build decoder done..")

    model = Model(inputs=inputs, outputs=out, name="SegNet")
    model.compile(optimizer = optimizers.Adam(lr = 1e-3), loss = 'categorical_crossentropy',metrics=[iou,'accuracy'])

    if model_summary is True:
        model.summary()

    return model

# %%
#Train the model
#Need to know how many images for train and validation, then compute steps manually.
tb = TensorBoard(log_dir='training_logs/test_log1', write_graph=True)
mc = ModelCheckpoint(mode='max', filepath='trained_models/test.h5', monitor='iou', save_best_only='True', save_weights_only='True', verbose=1)
es = EarlyStopping(mode='min', monitor='val_loss', patience=50, verbose=1)
callbacks = [tb, mc, es]
batch_size = 16
model=SegNet(input_shape=(256, 256, 3),batch_size=batch_size, n_labels=2, model_summary=True)
num_epochs = 20
model.fit(prepare_data.train_data_generator(batch_size=16),
                    validation_data=prepare_data.validation_data_generator(batch_size=16),epochs=num_epochs, 
                    verbose=1,steps_per_epoch=246, validation_steps=84,callbacks=callbacks)

# %%
model=SegNet(input_shape=(256, 256, 3), batch_size=16, n_labels=2, model_summary=True)
model.load_weights('trained_models/seg_resnet_2.h5')
result=model.evaluate(prepare_data.test_data_generator(batch_size=16),steps=85)
print(result)

# %%
model=SegNet(input_shape=(256, 256, 3), batch_size=16, n_labels=2, model_summary=True)
model.load_weights('trained_models/seg_resnet_2.h5')
flag=1
testing_gen = prepare_data.test_data_generator(batch_size=16, seed=23)
#testing_gen=PrepareData.images_without_label_data_generator(batch_size=16)
while(flag>0):
    flag=flag-1
    batch_img, batch_mask= next(testing_gen)
    #batch_img = next(testing_gen)
    pred_all = model.predict(batch_img)
    np.shape(pred_all)

    for i in range(0, np.shape(pred_all)[0]):
        fig = plt.figure(figsize=(20, 8))

        ax1 = fig.add_subplot(1, 3, 1)
        ax1.imshow(batch_img[i])
        ax1.title.set_text('Original Image')
        ax1.grid(b=None)

        ax2 = fig.add_subplot(1, 3, 2)
        ax2.set_title('Ground truth labels')
        ax2.imshow(prepare_data.onehot_to_rgb(batch_mask[i], prepare_data.id2code))
        ax2.grid(b=None)

        ax3 = fig.add_subplot(1, 3, 3)
        ax3.set_title('Predicted labels')
        #Use a different color for prediction
        new_color_code={0: (0, 0, 0), 1: (135,206,235)}
        ax3.imshow(prepare_data.onehot_to_rgb(pred_all[i], new_color_code))
        ax3.grid(b=None)
        plt.show()
# Out:
# Build enceder done..
# Build decoder done..
# Model: "SegNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(16, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# res1a_branch2a (Conv2D)         (16, 256, 256, 64)   256         input_1[0][0]
# __________________________________________________________________________________________________
# bn1a_branch2a (BatchNormalizati (16, 256, 256, 64)   256         res1a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (16, 256, 256, 64)   0           bn1a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1a_branch2b1 (Conv2D)        (16, 256, 256, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# bn1a_branch2b1 (BatchNormalizat (16, 256, 256, 64)   256         res1a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (16, 256, 256, 64)   0           bn1a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res1a_branch2c (Conv2D)         (16, 256, 256, 64)   4160        activation_1[0][0]
# __________________________________________________________________________________________________
# bn1a_branch2c (BatchNormalizati (16, 256, 256, 64)   256         res1a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (16, 256, 256, 64)   256         input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (16, 256, 256, 64)   0           bn1a_branch2c[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (16, 256, 256, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d (MaxP [(16, 128, 128, 64), 0           activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (16, 128, 128, 128)  8320        max_pooling_with_argmax2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (16, 128, 128, 128)  512         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (16, 128, 128, 128)  0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b1 (Conv2D)        (16, 128, 128, 128)  147584      activation_3[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b1 (BatchNormalizat (16, 128, 128, 128)  512         res2a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (16, 128, 128, 128)  0           bn2a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (16, 128, 128, 128)  16512       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (16, 128, 128, 128)  512         res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (16, 128, 128, 128)  8320        max_pooling_with_argmax2d[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (16, 128, 128, 128)  0           bn2a_branch2c[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (16, 128, 128, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_1 (Ma [(16, 64, 64, 128),  0           activation_5[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (16, 64, 64, 128)    16512       max_pooling_with_argmax2d_1[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (16, 64, 64, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (16, 64, 64, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b1 (Conv2D)        (16, 64, 64, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b1 (BatchNormalizat (16, 64, 64, 128)    512         res3a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (16, 64, 64, 128)    0           bn3a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b2 (Conv2D)        (16, 64, 64, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b2 (BatchNormalizat (16, 64, 64, 128)    512         res3a_branch2b2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (16, 64, 64, 128)    0           bn3a_branch2b2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (16, 64, 64, 128)    16512       activation_8[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (16, 64, 64, 128)    512         res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (16, 64, 64, 128)    0           bn3a_branch2c[0][0]
#                                                                  max_pooling_with_argmax2d_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (16, 64, 64, 128)    0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_2 (Ma [(16, 32, 32, 128),  0           activation_9[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (16, 32, 32, 256)    33024       max_pooling_with_argmax2d_2[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (16, 32, 32, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (16, 32, 32, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b1 (Conv2D)        (16, 32, 32, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b1 (BatchNormalizat (16, 32, 32, 256)    1024        res4a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (16, 32, 32, 256)    0           bn4a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b2 (Conv2D)        (16, 32, 32, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b2 (BatchNormalizat (16, 32, 32, 256)    1024        res4a_branch2b2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (16, 32, 32, 256)    0           bn4a_branch2b2[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b3 (Conv2D)        (16, 32, 32, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b3 (BatchNormalizat (16, 32, 32, 256)    1024        res4a_branch2b3[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (16, 32, 32, 256)    0           bn4a_branch2b3[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (16, 32, 32, 256)    65792       activation_13[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (16, 32, 32, 256)    1024        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (16, 32, 32, 256)    33024       max_pooling_with_argmax2d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (16, 32, 32, 256)    0           bn4a_branch2c[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (16, 32, 32, 256)    0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_3 (Ma [(16, 16, 16, 256),  0           activation_14[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (16, 16, 16, 256)    65792       max_pooling_with_argmax2d_3[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (16, 16, 16, 256)    1024        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (16, 16, 16, 256)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b1 (Conv2D)        (16, 16, 16, 256)    590080      activation_15[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b1 (BatchNormalizat (16, 16, 16, 256)    1024        res5a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (16, 16, 16, 256)    0           bn5a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b2 (Conv2D)        (16, 16, 16, 256)    590080      activation_16[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b2 (BatchNormalizat (16, 16, 16, 256)    1024        res5a_branch2b2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (16, 16, 16, 256)    0           bn5a_branch2b2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b3 (Conv2D)        (16, 16, 16, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b3 (BatchNormalizat (16, 16, 16, 256)    1024        res5a_branch2b3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (16, 16, 16, 256)    0           bn5a_branch2b3[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (16, 16, 16, 256)    65792       activation_18[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (16, 16, 16, 256)    1024        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (16, 16, 16, 256)    0           bn5a_branch2c[0][0]
#                                                                  max_pooling_with_argmax2d_3[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (16, 16, 16, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling_with_argmax2d_4 (Ma [(16, 8, 8, 256), (1 0           activation_19[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d (MaxUnpooling2D (16, 16, 16, 256)    0           max_pooling_with_argmax2d_4[0][0]
#                                                                  max_pooling_with_argmax2d_4[0][1]
# __________________________________________________________________________________________________
# res6a_branch2a (Conv2D)         (16, 16, 16, 256)    65792       max_unpooling2d[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2a (BatchNormalizati (16, 16, 16, 256)    1024        res6a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (16, 16, 16, 256)    0           bn6a_branch2a[0][0]
# __________________________________________________________________________________________________
# res6a_branch2b1 (Conv2D)        (16, 16, 16, 256)    590080      activation_20[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2b1 (BatchNormalizat (16, 16, 16, 256)    1024        res6a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (16, 16, 16, 256)    0           bn6a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res6a_branch2b2 (Conv2D)        (16, 16, 16, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2b2 (BatchNormalizat (16, 16, 16, 256)    1024        res6a_branch2b2[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (16, 16, 16, 256)    0           bn6a_branch2b2[0][0]
# __________________________________________________________________________________________________
# res6a_branch2b3 (Conv2D)        (16, 16, 16, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2b3 (BatchNormalizat (16, 16, 16, 256)    1024        res6a_branch2b3[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (16, 16, 16, 256)    0           bn6a_branch2b3[0][0]
# __________________________________________________________________________________________________
# res6a_branch2c (Conv2D)         (16, 16, 16, 256)    65792       activation_23[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2c (BatchNormalizati (16, 16, 16, 256)    1024        res6a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (16, 16, 16, 256)    0           bn6a_branch2c[0][0]
#                                                                  max_unpooling2d[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (16, 16, 16, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_1 (MaxUnpooling (16, 32, 32, 256)    0           activation_24[0][0]
#                                                                  max_pooling_with_argmax2d_3[0][1]
# __________________________________________________________________________________________________
# res7a_branch2a (Conv2D)         (16, 32, 32, 256)    65792       max_unpooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2a (BatchNormalizati (16, 32, 32, 256)    1024        res7a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (16, 32, 32, 256)    0           bn7a_branch2a[0][0]
# __________________________________________________________________________________________________
# res7a_branch2b1 (Conv2D)        (16, 32, 32, 256)    590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2b1 (BatchNormalizat (16, 32, 32, 256)    1024        res7a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (16, 32, 32, 256)    0           bn7a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res7a_branch2b2 (Conv2D)        (16, 32, 32, 256)    590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2b2 (BatchNormalizat (16, 32, 32, 256)    1024        res7a_branch2b2[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (16, 32, 32, 256)    0           bn7a_branch2b2[0][0]
# __________________________________________________________________________________________________
# res7a_branch2b3 (Conv2D)        (16, 32, 32, 256)    590080      activation_27[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2b3 (BatchNormalizat (16, 32, 32, 256)    1024        res7a_branch2b3[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (16, 32, 32, 256)    0           bn7a_branch2b3[0][0]
# __________________________________________________________________________________________________
# res7a_branch2c (Conv2D)         (16, 32, 32, 256)    65792       activation_28[0][0]
# __________________________________________________________________________________________________
# bn7a_branch2c (BatchNormalizati (16, 32, 32, 256)    1024        res7a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (16, 32, 32, 256)    0           bn7a_branch2c[0][0]
#                                                                  max_unpooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (16, 32, 32, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (16, 32, 32, 128)    32896       activation_29[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_2 (MaxUnpooling (16, 64, 64, 128)    0           conv2d_3[0][0]
#                                                                  max_pooling_with_argmax2d_2[0][1]
# __________________________________________________________________________________________________
# res8a_branch2a (Conv2D)         (16, 64, 64, 128)    16512       max_unpooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2a (BatchNormalizati (16, 64, 64, 128)    512         res8a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (16, 64, 64, 128)    0           bn8a_branch2a[0][0]
# __________________________________________________________________________________________________
# res8a_branch2b1 (Conv2D)        (16, 64, 64, 128)    147584      activation_30[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2b1 (BatchNormalizat (16, 64, 64, 128)    512         res8a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (16, 64, 64, 128)    0           bn8a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res8a_branch2b2 (Conv2D)        (16, 64, 64, 128)    147584      activation_31[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2b2 (BatchNormalizat (16, 64, 64, 128)    512         res8a_branch2b2[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (16, 64, 64, 128)    0           bn8a_branch2b2[0][0]
# __________________________________________________________________________________________________
# res8a_branch2c (Conv2D)         (16, 64, 64, 128)    16512       activation_32[0][0]
# __________________________________________________________________________________________________
# bn8a_branch2c (BatchNormalizati (16, 64, 64, 128)    512         res8a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (16, 64, 64, 128)    0           bn8a_branch2c[0][0]
#                                                                  max_unpooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (16, 64, 64, 128)    0           add_7[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_3 (MaxUnpooling (16, 128, 128, 128)  0           activation_33[0][0]
#                                                                  max_pooling_with_argmax2d_1[0][1]
# __________________________________________________________________________________________________
# res9a_branch2a (Conv2D)         (16, 128, 128, 128)  16512       max_unpooling2d_3[0][0]
# __________________________________________________________________________________________________
# bn9a_branch2a (BatchNormalizati (16, 128, 128, 128)  512         res9a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (16, 128, 128, 128)  0           bn9a_branch2a[0][0]
# __________________________________________________________________________________________________
# res9a_branch2b1 (Conv2D)        (16, 128, 128, 128)  147584      activation_34[0][0]
# __________________________________________________________________________________________________
# bn9a_branch2b1 (BatchNormalizat (16, 128, 128, 128)  512         res9a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (16, 128, 128, 128)  0           bn9a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res9a_branch2c (Conv2D)         (16, 128, 128, 128)  16512       activation_35[0][0]
# __________________________________________________________________________________________________
# bn9a_branch2c (BatchNormalizati (16, 128, 128, 128)  512         res9a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (16, 128, 128, 128)  0           bn9a_branch2c[0][0]
#                                                                  max_unpooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (16, 128, 128, 128)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (16, 128, 128, 64)   8256        activation_36[0][0]
# __________________________________________________________________________________________________
# max_unpooling2d_4 (MaxUnpooling (16, 256, 256, 64)   0           conv2d_4[0][0]
#                                                                  max_pooling_with_argmax2d[0][1]
# __________________________________________________________________________________________________
# res10a_branch2a (Conv2D)        (16, 256, 256, 64)   4160        max_unpooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn10a_branch2a (BatchNormalizat (16, 256, 256, 64)   256         res10a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (16, 256, 256, 64)   0           bn10a_branch2a[0][0]
# __________________________________________________________________________________________________
# res10a_branch2b1 (Conv2D)       (16, 256, 256, 64)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# bn10a_branch2b1 (BatchNormaliza (16, 256, 256, 64)   256         res10a_branch2b1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (16, 256, 256, 64)   0           bn10a_branch2b1[0][0]
# __________________________________________________________________________________________________
# res10a_branch2c (Conv2D)        (16, 256, 256, 64)   4160        activation_38[0][0]
# __________________________________________________________________________________________________
# bn10a_branch2c (BatchNormalizat (16, 256, 256, 64)   256         res10a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (16, 256, 256, 64)   0           bn10a_branch2c[0][0]
#                                                                  max_unpooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (16, 256, 256, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (16, 256, 256, 2)    130         activation_39[0][0]
# ==================================================================================================
# Total params: 8,782,594
# Trainable params: 8,768,002
# Non-trainable params: 14,592
# __________________________________________________________________________________________________
# Found 1360 images belonging to 2 classes.
# Found 1360 images belonging to 2 classes.

# %%
# %tensorboard --logdir training_logs/segnet_log1
#!tensorboard --logdir /tmp/whatever
